# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ruptures as rpt
from fertilizantes_utils import *
import locale
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf #, plot_ccf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

sns.set_style('darkgrid')

# Establecer el idioma español para fechas en Windows
locale.setlocale(locale.LC_TIME, 'Spanish_Spain.1252')
# Out:
# 'Spanish_Spain.1252'

# %%
# Importar datos:
df = pd.read_excel('data/predicción_precios_fertilizantes.xlsx', index_col='date')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 166 entries, 2011-01-31 to 2024-10-31
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fob_urea_kg                       150 non-null    float64
#  1   crude_oil_brent_usd_per_bbl       154 non-null    float64
#  2   natural_gas_europe_usd_per_mmbtu  154 non-null    float64
#  3   coal_australian_usd_per_mt        154 non-null    float64
#  4   coal_south_african_usd_per_mt     154 non-null    float64
#  5   inflación_mensual                 154 non-null    float64
#  6   ipc_diesel                        140 non-null    float64
#  7   precipitación_media_mm            156 non-null    float64
#  8   temp_media_Celsius                156 non-null    float64
#  9   baltic_dry_idx_last               154 non-null    float64
#  10  pct_pobreza_rural                 145 non-null    float64
#  11  fosfato diamónico 18-46-0         140 non-null    float64
#  12  muriato de potasio 0-0-60         140 non-null    float64
#  13  urea 46-0-0                       140 non-null    float64
# dtypes: float64(14)
# memory usage: 19.5 KB

# %%
# Renombrar algunas variables:
dict_nombres_fertilizantes = {
        "fosfato diamónico 18-46-0":"pvp_dap",
        "muriato de potasio 0-0-60":"pvp_mop",
        "urea 46-0-0":"pvp_urea"
        }

df = df.rename(columns=dict_nombres_fertilizantes)

# Definir variable objetivo:
variable_objetivo = 'pvp_urea'

# Filtrar variables objetivo no relevantes:
variables_objetivo_no_relevantes = list(dict_nombres_fertilizantes.values())
variables_objetivo_no_relevantes.remove(variable_objetivo)

# Lista de variables que por distintos motivos son excluidas del modelo:
variables_excluidas = ['coal_south_african_usd_per_mt', 'temp_media_Celsius', 'pct_pobreza_rural',
                       'natural_gas_europe_usd_per_mmbtu', 'coal_australian_usd_per_mt', 'inflación_mensual']

# Eliminar variables no relevantes:
df = df.drop(columns=variables_excluidas + variables_objetivo_no_relevantes)

# %% [markdown]
# ### Análisis Exploratorio de datos

# %%
# num_de_filas = ((df.shape[1] + 1) // 2)

# df.plot(
#     subplots=True,
#     layout=(num_de_filas, 2),
#     figsize=(15, 2 * num_de_filas),
#     sharex=False
#     )
# plt.show()

# %%
# Crear lista de nombres truncados de variables:
truncated_labels = [col[:15] + "..." if len(col) > 10 else col for col in df.columns]
posición_ticks = np.arange(len(df.columns))

# Graficar boxplot de variables originales:
sns.boxplot(df)
plt.xticks(ticks=posición_ticks, labels=truncated_labels, rotation=90, size=8)
plt.title("Boxplot de variables")
plt.show()

# %%
plot_correlation_heatmap(df, method='pearson')

# %% [markdown]
# ### Ingeniería de variables

# %%
# Calcular volatilidad con ventanas de 6 y 12 meses:
ventanas = (6, 12)

for v in ventanas:
    df[f'volatilidad_bdi_{v}m'] = df['baltic_dry_idx_last']\
        .apply(np.log)\
        .diff()\
        .rolling(window=v)\
        .std()

# Interacción crudo europeo - BDI:
df['inter_bdi_crude'] = df['baltic_dry_idx_last'] * df['crude_oil_brent_usd_per_bbl']

# %%
# Calcular coeficiente de variación de precipitación para diferentes ventanas.
# El coeficiente de variación es una medida de la variabilidad relativa de una serie en relación con su media.

ventanas = (12, 18) # 3 y 6 son estacionarias ergo exógenas y no tienen impacto.

for v in ventanas:
    df[f'coef_var_precip_{v}m'] = df['precipitación_media_mm'].rolling(window=v).std() \
        / df['precipitación_media_mm'].rolling(window=v).mean()

# %% [markdown]
# #### Transformación log de variables:

# %%
# Crear un DataFrame sin NaN:
df_sin_na = df.dropna()

# Crear DataFrame para variables logarítmicas:
ln_data = pd.DataFrame(index=df_sin_na.index)

# Variables porcentuales:
variables_no_log_transformables = ['inflación_mensual', 'pct_pobreza_rural', 'var_pct_pobreza_rural', 'coef_var_pobreza_rural',
                                   'precipitación_media_m', 'precipitación_media_m2', 'coef_var_precip_12m', 'coef_var_precip_18m',
                                   'coef_var_precip_24m', 'volatilidad_bdi_3m', 'volatilidad_bdi_6m', 'volatilidad_bdi_12m']

variables_log_transformadas = []

# Transformación logarítmica de las variables:
for col in df_sin_na.columns:
    
    # Transformación logarítmica de las variables no transformables:
    if col not in variables_no_log_transformables:
        
        # Añadir a lista de variables log-transformadas:
        variables_log_transformadas.append(col)
        
        # Transformar:
        ln_data['ln_' + col] = df_sin_na[col].apply(np.log)
    else:
        ln_data[col] = df_sin_na[col]

# %% [markdown]
# ### EDA post ingeniería de variables

# %%
# Crar un DataFrame que solo contenga variables con tranformación log:
df_variables_log_transformadas = ln_data[["ln_" + col for col in variables_log_transformadas]]

# Renombrar variables a sus denominaciones originales para lograr empates en gráfico:
df_variables_log_transformadas.columns = variables_log_transformadas

# Comparar forma original de las variables y su transformación log:
plot_comparison(df_sin_na[variables_log_transformadas], df_variables_log_transformadas, prefix='ln_')

# %%
# Variable objetivo:
variable_objetivo = "ln_pvp_urea"

# Variables excluidas en segunda instancia:
variables_excluidas_2 = ['ln_baltic_dry_idx_last', 'ln_precipitación_media_mm', 'coef_var_precip_18m', 'volatilidad_bdi_12m'] # 'coef_var_precip_12m'
ln_data = ln_data.drop(columns=variables_excluidas_2)

# Extraer variables predictoras:
X = ln_data.drop(columns=variable_objetivo)

# Extraer variable objetivo:
y = ln_data[variable_objetivo]

# %%
# Calcular el factor de inflación de varianza (VIF) de las variables explicativas originales:
calcular_vif(X)
# Out:
#                          Variable       VIF
# 0                  ln_fob_urea_kg  3.927598
# 1                   ln_ipc_diesel  3.670065
# 2              ln_inter_bdi_crude  3.018541
# 3  ln_crude_oil_brent_usd_per_bbl  3.010859
# 4             coef_var_precip_12m  1.447890
# 5              volatilidad_bdi_6m  1.215060

# %%
num_de_filas = ((ln_data.shape[1] + 1) // 2)

# Revisar variables tras transformaciones:
ln_data.plot(
    subplots=True,
    layout=(num_de_filas, 2), # filas, columnas
    figsize=(15, 2 * num_de_filas),
    sharex=False
    )
plt.suptitle("Series de tiempo transformadas")
plt.tight_layout()
plt.show()

# %%
truncated_labels = [col[:15] + "..." if len(col) > 10 else col for col in ln_data.columns]
posición_ticks = np.arange(len(ln_data.columns))

sns.boxplot(ln_data)
plt.xticks(ticks=posición_ticks, labels=truncated_labels, rotation=90, size=8)
plt.title("Boxplot de variables transformadas")
plt.show()

# %%
plot_correlation_heatmap(ln_data, method='spearman')

# %% [markdown]
# ### Regresión Lineal Simple

# %%
# Selección automática de variables significativas:
modelo_ols_significativo, variables_significativas_ols = ols_backward_elimination(X, y, significance_level=0.05)

print(modelo_ols_significativo.summary())
# Out:
# variable eliminada: coef_var_precip_12m; p-valor: 0.3331
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            ln_pvp_urea   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     267.6
# Date:               vi., 13 dic. 2024   Prob (F-statistic):           2.66e-65
# Time:                        13:29:06   Log-Likelihood:                 133.71
# No. Observations:                 132   AIC:                            -255.4
# Df Residuals:                     126   BIC:                            -238.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -2.1417      0.362     -5.916      0.000      -2.858      -1.425
# ln_fob_urea_kg                     0.4195      0.040     10.499      0.000       0.340       0.499
# ln_crude_oil_brent_usd_per_bbl     0.4393      0.039     11.204      0.000       0.362       0.517
# ln_ipc_diesel                      0.4353      0.062      7.058      0.000       0.313       0.557
# volatilidad_bdi_6m                 0.4290      0.073      5.852      0.000       0.284       0.574
# ln_inter_bdi_crude                -0.1771      0.019     -9.501      0.000      -0.214      -0.140
# ==============================================================================
# Omnibus:                        1.151   Durbin-Watson:                   0.675
# Prob(Omnibus):                  0.562   Jarque-Bera (JB):                1.077
# Skew:                           0.050   Prob(JB):                        0.584
# Kurtosis:                       2.569   Cond. No.                         614.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calcular VIF de las variables significativas del modelo OLS:
calcular_vif(X[variables_significativas_ols])
# Out:
#                          Variable       VIF
# 0                  ln_fob_urea_kg  3.865807
# 1                   ln_ipc_diesel  3.331149
# 2  ln_crude_oil_brent_usd_per_bbl  2.992451
# 3              ln_inter_bdi_crude  2.941070
# 4              volatilidad_bdi_6m  1.125377

# %% [markdown]
# ## VECM
#
# ### Revisar VIF de variables para VECM

# %%
# Seleccionar variables independientes relevantes para el modelo VECM:
X_vecm = ln_data.drop(columns=variable_objetivo)

# Revisar VIF de variables para VECM:
print(calcular_vif(X_vecm))

# Adjuntar variable objetivo a variables del modelo VECM:
vars_modelo_vecm = X_vecm.columns.tolist()
vars_modelo_vecm.append(variable_objetivo)

# Crear DataFrame:
df_vars_vecm = ln_data[vars_modelo_vecm]
# Out:
#                          Variable       VIF
# 0                  ln_fob_urea_kg  3.927598
# 1                   ln_ipc_diesel  3.670065
# 2              ln_inter_bdi_crude  3.018541
# 3  ln_crude_oil_brent_usd_per_bbl  3.010859
# 4             coef_var_precip_12m  1.447890
# 5              volatilidad_bdi_6m  1.215060

# %%
# plot_scatter_matrix(df_vars_vecm) #, trendline=True)

# %% [markdown]
# ### Primer supuesto VECM: variables son no estacionarias en niveles (forma original)

# %%
# Revisar si las variables son no estacionarias bajo supuesto del modelo VECM:
evaluar_estacionareidad_vars = evaluar_estacionareidad(df_vars_vecm)

evaluar_estacionareidad_vars
# Out:
#                          variable  valor_p_adfuller  valor_p_kpss  \
# 0                  ln_fob_urea_kg          0.216709      0.020516
# 1  ln_crude_oil_brent_usd_per_bbl          0.212587      0.100000
# 2                   ln_ipc_diesel          0.963462      0.010000
# 3              volatilidad_bdi_6m          0.107956      0.053137
# 4              ln_inter_bdi_crude          0.072078      0.049273
# 5             coef_var_precip_12m          0.130529      0.100000
# 6                     ln_pvp_urea          0.256189      0.029500
#
#    adfuller_rechazar_H0  kpss_rechazar_H0 estado_estacionario
# 0                 False              True     No estacionario
# 1                 False             False            No claro
# 2                 False              True     No estacionario
# 3                 False             False            No claro
# 4                 False              True     No estacionario
# 5                 False             False            No claro
# 6                 False              True     No estacionario

# %%
# Filtrar variables con estacionareidad no clara:
estacionareidad_no_clara = df_vars_vecm[evaluar_estacionareidad_vars.query("estado_estacionario == 'No claro'")['variable']]

# Revisar no estacionareidad visualmente:
estacionareidad_no_clara.plot(subplots=True, figsize=(5, 7))
plt.suptitle("Revisar no estacionareidad de variables no claras en I(0))")
plt.tight_layout()
plt.show()

# %%
# Definir todas las variables como no estacionarias:
evaluar_estacionareidad_vars['estado_estacionario'] = "No estacionario"

# %% [markdown]
# **Conclusión 1:** A pesar de que en niveles existen variables con resultado de estacionareidad "no claro", visualmente existe un grado alto de plausibilidad de que estas variables son no estacionarias.
#
# ### Segundo supuesto VECM: las variables son estacionarias tras I(1)

# %%
# Obtener lista de variables no estacionarias:
variables_no_estacionarias = evaluar_estacionareidad_vars.query("estado_estacionario != 'Estacionario'")['variable'].tolist()

df_diferenciación_I1 = df_vars_vecm[variables_no_estacionarias]\
    .diff()\
    .dropna()\
    .add_suffix("_d1")

# Evaluar si las variables no estacionarias se convierten tras primera diferenciación:
evaluar_estacionareidad_vars_I1 = evaluar_estacionareidad(df_diferenciación_I1)

evaluar_estacionareidad_vars_I1
# Out:
#                             variable  valor_p_adfuller  valor_p_kpss  \
# 0                  ln_fob_urea_kg_d1      6.782078e-02           0.1
# 1  ln_crude_oil_brent_usd_per_bbl_d1      3.572860e-13           0.1
# 2                   ln_ipc_diesel_d1      3.881646e-29           0.1
# 3              volatilidad_bdi_6m_d1      1.483802e-09           0.1
# 4              ln_inter_bdi_crude_d1      2.172076e-21           0.1
# 5             coef_var_precip_12m_d1      6.099490e-05           0.1
# 6                     ln_pvp_urea_d1      4.619871e-02           0.1
#
#    adfuller_rechazar_H0  kpss_rechazar_H0 estado_estacionario
# 0                 False             False            No claro
# 1                  True             False        Estacionario
# 2                  True             False        Estacionario
# 3                  True             False        Estacionario
# 4                  True             False        Estacionario
# 5                  True             False        Estacionario
# 6                  True             False        Estacionario

# %%
num_de_filas = ((df_diferenciación_I1.shape[1] + 1) // 2)

df_diferenciación_I1.plot(
    subplots=True,
    layout=(num_de_filas, 2), # filas, columnas
    figsize=(12, 2 * num_de_filas),
    sharex=False
    )
plt.suptitle("Revisar estacionareidad tras I(1)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Conclusión:** Aunque algunos resultados de estacionareidad tras I(1) por KPSS y ADF aparecen como "no claros", las gráficas sugieren con alto grado de plausibilidad que todas las variables son estacionarias. Por tanto, se cumple el segundo supuesto del modelo VECM.
#
# ### Ruptura estructural

# %%
# Crear dataframe solamente con variables no estacionarias:
df_endógenas_vecm = df_vars_vecm[variables_no_estacionarias]

# Crear dataframe de variables exógenas al modelo de cointegración (en este caso, las variables estacionarias):
set_vars_exógenas = set(df_vars_vecm.columns) - set(variables_no_estacionarias)
df_exógenas_vecm = df_vars_vecm[list(set_vars_exógenas)]

# # Eliminar las variables fertilizantes que no son de interés: 
# columns_to_drop = [col for col in lista_fertilizantes if col != variable_objetivo]

# df_endógenas_vecm = df_no_estacionarias.drop(columns=columns_to_drop)

print("Variables seleccionadas como exógenas al ser estacionarias: ", set_vars_exógenas)

df_endógenas_vecm.to_excel('data/df_endógenas_vecm.xlsx', index=True)
# Out:
# Variables seleccionadas como exógenas al ser estacionarias:  set()

# %%
# Dividir en variable dependiente e independientes
y = df_endógenas_vecm[variable_objetivo]
X = df_endógenas_vecm.drop(columns=[variable_objetivo])

# Detectar rupturas estructurales
ruptura_estructural = detect_structural_breaks(y, X, model_type="rbf", n_bkps=1)

# Mostrar resultados
print(ruptura_estructural)
# Out:
#   break_date  F-Statistic   p-value
# 0 2021-05-31    11.008158  0.001191

# %%
# Out:
# Timestamp('2021-05-31 00:00:00')

# %%
# X['ln_fob_urea_kg'].plot()
y.plot()
plt.axvspan(ruptura_estructural.loc[0, 'break_date'], X.index[-1], color='red', alpha=0.15, label="Período pos-ruptura")
plt.title("Período pos-ruptura estructural para el precio de la urea 46-0-0")
plt.legend()

# %%
# Crear DataFrame vacío con el mismo índice que df_endógenas_vecm:
dummies_ruptura = pd.DataFrame(index=df_endógenas_vecm.index)

# Ordenar las fechas de ruptura
fechas_ruptura = sorted(pd.to_datetime(ruptura_estructural['break_date'].values))

# Iterar sobre las fechas de ruptura, manejando intervalos entre rupturas
for i, fecha in enumerate(fechas_ruptura):
    # Formatear la fecha para el nombre de la columna
    str_fecha = fecha.strftime('%b%Y').replace(".", "_")
    
    # Definir el fin del intervalo como la siguiente fecha de ruptura o el final del índice
    if i < len(fechas_ruptura) - 1:
        fin_intervalo = fechas_ruptura[i + 1]
    else:
        fin_intervalo = dummies_ruptura.index.max() + pd.Timedelta(days=1)  # Asegura incluir el último día
    
    # Crear la dummy para el intervalo actual
    dummies_ruptura['ruptura_' + str_fecha] = (
        (dummies_ruptura.index >= fecha) & (dummies_ruptura.index < fin_intervalo)
    ).astype(int)

# Unir variables dummy al DataFrame de variables exógenas:
df_exógenas_vecm = df_exógenas_vecm.join(dummies_ruptura, how="inner").add_prefix('exog_')

df_exógenas_vecm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 132 entries, 2013-01-31 to 2023-12-31
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   exog_ruptura_may_2021  132 non-null    int32
# dtypes: int32(1)
# memory usage: 1.5 KB

# %%
# df_completo = df_endógenas_vecm.join(df_exógenas_vecm, how='inner')

# df_completo.to_excel("data/df_completo.xlsx", index=True)

# %%
df_ols_previo = df_endógenas_vecm.join(df_exógenas_vecm, how='inner')
X_ols = df_ols_previo.drop(columns=variable_objetivo)
y_ols = df_ols_previo[variable_objetivo]

# Selección automática de variables significativas:
modelo_ols_significativo, variables_significativas_ols = ols_backward_elimination(X_ols, y_ols, significance_level=0.05)

print(modelo_ols_significativo.summary())
# Out:
# variable eliminada: coef_var_precip_12m; p-valor: 0.2230
# variable eliminada: ln_ipc_diesel; p-valor: 0.2319
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            ln_pvp_urea   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     289.9
# Date:               vi., 13 dic. 2024   Prob (F-statistic):           2.63e-67
# Time:                        13:29:19   Log-Likelihood:                 138.56
# No. Observations:                 132   AIC:                            -265.1
# Df Residuals:                     126   BIC:                            -247.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -0.0940      0.183     -0.514      0.608      -0.456       0.268
# ln_fob_urea_kg                     0.4346      0.036     12.177      0.000       0.364       0.505
# ln_crude_oil_brent_usd_per_bbl     0.4148      0.036     11.373      0.000       0.343       0.487
# volatilidad_bdi_6m                 0.4124      0.071      5.822      0.000       0.272       0.553
# ln_inter_bdi_crude                -0.1697      0.018     -9.684      0.000      -0.204      -0.135
# exog_ruptura_may_2021              0.2335      0.029      7.951      0.000       0.175       0.292
# ==============================================================================
# Omnibus:                        1.168   Durbin-Watson:                   0.692
# Prob(Omnibus):                  0.558   Jarque-Bera (JB):                1.094
# Skew:                           0.058   Prob(JB):                        0.579
# Kurtosis:                       2.569   Cond. No.                         300.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Cointegración

# %% [markdown]
# El **Vector AutoRegresivo** (VAR) es un modelo econométrico que captura las relaciones dinámicas entre varias series temporales tratándolas como variables endógenas. A diferencia de modelos univariados, el VAR permite que cada variable dependa de sus propios rezagos y de los rezagos de las demás, sin suponer relaciones causales específicas. Esto lo hace útil para analizar cómo los cambios en una variable afectan a las demás a lo largo del tiempo. Es ideal para identificar patrones de interdependencia y realizar análisis de impacto como impulso-respuesta o descomposición de varianza.

# %%
from statsmodels.tsa.api import VAR

# Ajusta un modelo VAR preliminar
modelo_var = VAR(df_endógenas_vecm, freq='ME')
orden_rezagos = modelo_var.select_order(maxlags=6) # 6 es más consistente
print(orden_rezagos.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      -26.05      -25.89   4.874e-12      -25.98
# 1     -38.01*     -36.75*  3.116e-17*     -37.50*
# 2      -37.94      -35.58   3.351e-17      -36.98
# 3      -37.67      -34.21   4.460e-17      -36.27
# 4      -37.39      -32.82   6.155e-17      -35.53
# 5      -37.45      -31.78   6.102e-17      -35.15
# 6      -37.42      -30.64   6.845e-17      -34.67
# -------------------------------------------------

# %%
# Obtener el valor de lags óptimo según HQIC:
criterio = 'fpe'
maxlags_óptimo = 6 # orden_rezagos.selected_orders[criterio]

print(f"Número de lags óptimo según criterio {criterio.upper()}: ", maxlags_óptimo)
# Out:
# Número de lags óptimo según criterio FPE:  6

# %% [markdown]
# La **prueba de Johansen** es un método econométrico utilizado para identificar relaciones de equilibrio a largo plazo (cointegración) entre múltiples series temporales no estacionarias. A diferencia de otros enfoques, como *Engle-Granger*, permite analizar más de dos variables simultáneamente. La prueba utiliza un modelo VAR para evaluar si existe una combinación lineal estacionaria entre las series. Sus resultados indican cuántos vectores de cointegración existen, lo que ayuda a decidir si las variables tienen una relación estable a largo plazo y si se debe utilizar un modelo como el VECM para capturar dichas dinámicas.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

cointegración_johansen = coint_johansen(df_endógenas_vecm, det_order=0, k_ar_diff=maxlags_óptimo)

estadísticos_de_traza = cointegración_johansen.lr1
valores_críticos = cointegración_johansen.cvt

print("Estadísticos de traza:\n", estadísticos_de_traza)
print("Valores críticos:\n[1% | 5% | 10%]\n", valores_críticos)
# Out:
# Estadísticos de traza:
#  [168.95941523 100.09793268  62.19692197  31.29537083  17.24809787
#    7.73998597   1.83218137]
# Valores críticos:
# [1% | 5% | 10%]
#  [[120.3673 125.6185 135.9825]
#  [ 91.109   95.7542 104.9637]
#  [ 65.8202  69.8189  77.8202]
#  [ 44.4929  47.8545  54.6815]
#  [ 27.0669  29.7961  35.4628]
#  [ 13.4294  15.4943  19.9349]
#  [  2.7055   3.8415   6.6349]]

# %%
# Extraer columna del 5% de nivel de confianza:
valores_críticos_5_pct = valores_críticos[:, 1]  

# Establecer vectores de cointegración base r=0:
r = 0

# Determinar r automáticamente:
for i, (trace, critical) in enumerate(zip(estadísticos_de_traza, valores_críticos_5_pct)):
    if trace > critical:
        # Incrementar r si se rechaza la hipótesis nula:
        r = i + 1

print(f"Número de vectores de cointegración (r): {r}")
# Out:
# Número de vectores de cointegración (r): 2

# %%
from statsmodels.tsa.vector_ar.vecm import VECM

# Ajustar el modelo VECM
modelo_vecm = VECM(
    df_endógenas_vecm,
    exog=df_exógenas_vecm, # Variables estacionarias
    k_ar_diff=maxlags_óptimo,  # Número de rezagos diferenciales basado en el VAR
    coint_rank=r,  # Número de vectores de cointegración, según Johansen
    deterministic='ci',
    freq='ME'
    ).fit()

# Resumen del modelo
print(modelo_vecm.summary())
# Out:
#     Det. terms outside the coint. relation & lagged endog. parameters for equation ln_fob_urea_kg
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# exog1                                 0.1291      0.080      1.613      0.107      -0.028       0.286
# L1.ln_fob_urea_kg                     0.1205      0.101      1.191      0.234      -0.078       0.319
# L1.ln_crude_oil_brent_usd_per_bbl     0.4226      0.125      3.382      0.001       0.178       0.668
# L1.ln_ipc_diesel                      0.5495      0.234      2.345      0.019       0.090       1.009
# L1.volatilidad_bdi_6m                -0.0455      0.140     -0.325      0.745      -0.320       0.229
# L1.ln_inter_bdi_crude                -0.1531      0.060     -2.549      0.011      -0.271      -0.035
# L1.coef_var_precip_12m                0.1393      0.483      0.288      0.773      -0.808       1.086
# L1.ln_pvp_urea                       -0.2973      0.269     -1.104      0.270      -0.825       0.231
# L2.ln_fob_urea_kg                     0.0865      0.099      0.872      0.383      -0.108       0.281
# L2.ln_crude_oil_brent_usd_per_bbl    -0.0028      0.125     -0.022      0.982      -0.248       0.243
# L2.ln_ipc_diesel                      0.1774      0.257      0.690      0.490      -0.327       0.682
# L2.volatilidad_bdi_6m                 0.2543      0.142      1.792      0.073      -0.024       0.533
# L2.ln_inter_bdi_crude                -0.1460      0.052     -2.793      0.005      -0.248      -0.044
# L2.coef_var_precip_12m               -0.9258      0.500     -1.850      0.064      -1.907       0.055
# L2.ln_pvp_urea                       -0.9703      0.259     -3.750      0.000      -1.477      -0.463
# L3.ln_fob_urea_kg                     0.1510      0.099      1.519      0.129      -0.044       0.346
# L3.ln_crude_oil_brent_usd_per_bbl     0.4509      0.118      3.837      0.000       0.221       0.681
# L3.ln_ipc_diesel                      0.3673      0.258      1.425      0.154      -0.138       0.873
# L3.volatilidad_bdi_6m                -0.1763      0.139     -1.272      0.203      -0.448       0.095
# L3.ln_inter_bdi_crude                -0.1165      0.047     -2.468      0.014      -0.209      -0.024
# L3.coef_var_precip_12m                0.5999      0.486      1.234      0.217      -0.353       1.553
# L3.ln_pvp_urea                       -0.5626      0.255     -2.209      0.027      -1.062      -0.063
# L4.ln_fob_urea_kg                     0.0819      0.097      0.841      0.400      -0.109       0.273
# L4.ln_crude_oil_brent_usd_per_bbl     0.0954      0.116      0.820      0.412      -0.133       0.323
# L4.ln_ipc_diesel                      0.2386      0.255      0.935      0.350      -0.261       0.738
# L4.volatilidad_bdi_6m                 0.0893      0.137      0.654      0.513      -0.178       0.357
# L4.ln_inter_bdi_crude                -0.1231      0.046     -2.685      0.007      -0.213      -0.033
# L4.coef_var_precip_12m               -0.9234      0.468     -1.973      0.049      -1.841      -0.006
# L4.ln_pvp_urea                       -0.1119      0.240     -0.467      0.641      -0.582       0.358
# L5.ln_fob_urea_kg                     0.0667      0.090      0.744      0.457      -0.109       0.242
# L5.ln_crude_oil_brent_usd_per_bbl    -0.0197      0.109     -0.181      0.857      -0.233       0.194
# L5.ln_ipc_diesel                      0.3921      0.252      1.557      0.120      -0.102       0.886
# L5.volatilidad_bdi_6m                 0.1621      0.139      1.169      0.243      -0.110       0.434
# L5.ln_inter_bdi_crude                -0.0537      0.039     -1.363      0.173      -0.131       0.023
# L5.coef_var_precip_12m               -0.3867      0.450     -0.860      0.390      -1.268       0.494
# L5.ln_pvp_urea                        0.6840      0.213      3.212      0.001       0.267       1.101
# L6.ln_fob_urea_kg                    -0.1050      0.087     -1.207      0.228      -0.276       0.066
# L6.ln_crude_oil_brent_usd_per_bbl     0.1872      0.100      1.864      0.062      -0.010       0.384
# L6.ln_ipc_diesel                      0.5491      0.216      2.536      0.011       0.125       0.973
# L6.volatilidad_bdi_6m                 0.0343      0.126      0.273      0.784      -0.212       0.280
# L6.ln_inter_bdi_crude                -0.0771      0.034     -2.275      0.023      -0.144      -0.011
# L6.coef_var_precip_12m                0.3587      0.461      0.778      0.437      -0.545       1.263
# L6.ln_pvp_urea                       -0.6492      0.216     -3.011      0.003      -1.072      -0.227
# Det. terms outside the coint. relation & lagged endog. parameters for equation ln_crude_oil_brent_usd_per_bbl
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# exog1                                 0.1809      0.070      2.573      0.010       0.043       0.319
# L1.ln_fob_urea_kg                    -0.0387      0.089     -0.435      0.663      -0.213       0.135
# L1.ln_crude_oil_brent_usd_per_bbl     0.3183      0.110      2.898      0.004       0.103       0.534
# L1.ln_ipc_diesel                      0.5436      0.206      2.640      0.008       0.140       0.947
# L1.volatilidad_bdi_6m                -0.0478      0.123     -0.389      0.697      -0.289       0.193
# L1.ln_inter_bdi_crude                -0.0530      0.053     -1.004      0.315      -0.157       0.050
# L1.coef_var_precip_12m                0.1651      0.425      0.389      0.697      -0.667       0.997
# L1.ln_pvp_urea                       -0.7460      0.237     -3.152      0.002      -1.210      -0.282
# L2.ln_fob_urea_kg                     0.0387      0.087      0.444      0.657      -0.132       0.209
# L2.ln_crude_oil_brent_usd_per_bbl    -0.0605      0.110     -0.549      0.583      -0.276       0.155
# L2.ln_ipc_diesel                      0.7981      0.226      3.531      0.000       0.355       1.241
# L2.volatilidad_bdi_6m                -0.0729      0.125     -0.584      0.559      -0.317       0.172
# L2.ln_inter_bdi_crude                -0.0146      0.046     -0.319      0.750      -0.105       0.075
# L2.coef_var_precip_12m                0.1246      0.440      0.283      0.777      -0.737       0.987
# L2.ln_pvp_urea                       -0.0997      0.227     -0.439      0.661      -0.545       0.346
# L3.ln_fob_urea_kg                     0.0885      0.087      1.013      0.311      -0.083       0.260
# L3.ln_crude_oil_brent_usd_per_bbl     0.0127      0.103      0.123      0.902      -0.190       0.215
# L3.ln_ipc_diesel                      0.9678      0.227      4.272      0.000       0.524       1.412
# L3.volatilidad_bdi_6m                -0.1679      0.122     -1.378      0.168      -0.407       0.071
# L3.ln_inter_bdi_crude                -0.0716      0.041     -1.725      0.085      -0.153       0.010
# L3.coef_var_precip_12m               -0.4214      0.427     -0.986      0.324      -1.259       0.416
# L3.ln_pvp_urea                        0.0667      0.224      0.298      0.766      -0.372       0.505
# L4.ln_fob_urea_kg                     0.0092      0.086      0.108      0.914      -0.158       0.177
# L4.ln_crude_oil_brent_usd_per_bbl     0.0855      0.102      0.837      0.403      -0.115       0.286
# L4.ln_ipc_diesel                      0.8121      0.224      3.624      0.000       0.373       1.251
# L4.volatilidad_bdi_6m                -0.1229      0.120     -1.023      0.306      -0.358       0.112
# L4.ln_inter_bdi_crude                -0.0886      0.040     -2.200      0.028      -0.168      -0.010
# L4.coef_var_precip_12m                0.1701      0.411      0.414      0.679      -0.636       0.976
# L4.ln_pvp_urea                       -0.3895      0.211     -1.848      0.065      -0.802       0.024
# L5.ln_fob_urea_kg                     0.0861      0.079      1.094      0.274      -0.068       0.240
# L5.ln_crude_oil_brent_usd_per_bbl     0.0410      0.096      0.428      0.669      -0.147       0.229
# L5.ln_ipc_diesel                     -0.4062      0.221     -1.835      0.066      -0.840       0.028
# L5.volatilidad_bdi_6m                -0.1795      0.122     -1.472      0.141      -0.418       0.059
# L5.ln_inter_bdi_crude                -0.0555      0.035     -1.604      0.109      -0.123       0.012
# L5.coef_var_precip_12m               -0.6179      0.395     -1.564      0.118      -1.392       0.156
# L5.ln_pvp_urea                        0.3194      0.187      1.706      0.088      -0.047       0.686
# L6.ln_fob_urea_kg                    -0.0735      0.076     -0.961      0.336      -0.223       0.076
# L6.ln_crude_oil_brent_usd_per_bbl     0.0290      0.088      0.328      0.743      -0.144       0.202
# L6.ln_ipc_diesel                     -0.9062      0.190     -4.763      0.000      -1.279      -0.533
# L6.volatilidad_bdi_6m                 0.1409      0.110      1.277      0.202      -0.075       0.357
# L6.ln_inter_bdi_crude                -0.0613      0.030     -2.058      0.040      -0.120      -0.003
# L6.coef_var_precip_12m               -0.3606      0.405     -0.890      0.374      -1.155       0.434
# L6.ln_pvp_urea                        0.3421      0.189      1.806      0.071      -0.029       0.713
#      Det. terms outside the coint. relation & lagged endog. parameters for equation ln_ipc_diesel
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# exog1                                 0.0883      0.035      2.534      0.011       0.020       0.157
# L1.ln_fob_urea_kg                     0.0074      0.044      0.167      0.867      -0.079       0.094
# L1.ln_crude_oil_brent_usd_per_bbl     0.0582      0.054      1.069      0.285      -0.048       0.165
# L1.ln_ipc_diesel                     -0.3732      0.102     -3.658      0.000      -0.573      -0.173
# L1.volatilidad_bdi_6m                -0.1630      0.061     -2.678      0.007      -0.282      -0.044
# L1.ln_inter_bdi_crude                -0.0319      0.026     -1.219      0.223      -0.083       0.019
# L1.coef_var_precip_12m                0.4196      0.210      1.995      0.046       0.007       0.832
# L1.ln_pvp_urea                        0.0428      0.117      0.365      0.715      -0.187       0.273
# L2.ln_fob_urea_kg                     0.0437      0.043      1.012      0.312      -0.041       0.128
# L2.ln_crude_oil_brent_usd_per_bbl    -0.0708      0.055     -1.298      0.194      -0.178       0.036
# L2.ln_ipc_diesel                     -0.1824      0.112     -1.628      0.103      -0.402       0.037
# L2.volatilidad_bdi_6m                -0.0206      0.062     -0.334      0.739      -0.142       0.101
# L2.ln_inter_bdi_crude                -0.0280      0.023     -1.232      0.218      -0.073       0.017
# L2.coef_var_precip_12m                0.0788      0.218      0.361      0.718      -0.348       0.506
# L2.ln_pvp_urea                        0.0216      0.113      0.192      0.848      -0.199       0.242
# L3.ln_fob_urea_kg                     0.0275      0.043      0.635      0.525      -0.057       0.112
# L3.ln_crude_oil_brent_usd_per_bbl     0.0459      0.051      0.896      0.370      -0.054       0.146
# L3.ln_ipc_diesel                      0.0367      0.112      0.327      0.743      -0.183       0.257
# L3.volatilidad_bdi_6m                -0.0967      0.060     -1.603      0.109      -0.215       0.022
# L3.ln_inter_bdi_crude                -0.0020      0.021     -0.097      0.923      -0.042       0.038
# L3.coef_var_precip_12m                0.2160      0.212      1.020      0.308      -0.199       0.631
# L3.ln_pvp_urea                       -0.1084      0.111     -0.978      0.328      -0.326       0.109
# L4.ln_fob_urea_kg                    -0.0237      0.042     -0.560      0.576      -0.107       0.059
# L4.ln_crude_oil_brent_usd_per_bbl    -0.0845      0.051     -1.669      0.095      -0.184       0.015
# L4.ln_ipc_diesel                      0.1112      0.111      1.001      0.317      -0.106       0.329
# L4.volatilidad_bdi_6m                -0.1612      0.059     -2.710      0.007      -0.278      -0.045
# L4.ln_inter_bdi_crude                 0.0007      0.020      0.036      0.972      -0.038       0.040
# L4.coef_var_precip_12m                0.0478      0.204      0.235      0.815      -0.352       0.447
# L4.ln_pvp_urea                        0.0131      0.104      0.125      0.900      -0.192       0.218
# L5.ln_fob_urea_kg                     0.0104      0.039      0.266      0.790      -0.066       0.087
# L5.ln_crude_oil_brent_usd_per_bbl     0.0038      0.047      0.081      0.935      -0.089       0.097
# L5.ln_ipc_diesel                      0.1830      0.110      1.668      0.095      -0.032       0.398
# L5.volatilidad_bdi_6m                 0.0644      0.060      1.066      0.286      -0.054       0.183
# L5.ln_inter_bdi_crude                -0.0058      0.017     -0.340      0.734      -0.039       0.028
# L5.coef_var_precip_12m               -0.3779      0.196     -1.931      0.054      -0.762       0.006
# L5.ln_pvp_urea                        0.0488      0.093      0.526      0.599      -0.133       0.231
# L6.ln_fob_urea_kg                    -0.0367      0.038     -0.969      0.333      -0.111       0.038
# L6.ln_crude_oil_brent_usd_per_bbl    -0.0327      0.044     -0.747      0.455      -0.118       0.053
# L6.ln_ipc_diesel                      0.2184      0.094      2.317      0.021       0.034       0.403
# L6.volatilidad_bdi_6m                 0.0443      0.055      0.810      0.418      -0.063       0.151
# L6.ln_inter_bdi_crude                -0.0081      0.015     -0.547      0.584      -0.037       0.021
# L6.coef_var_precip_12m                0.0183      0.201      0.091      0.927      -0.375       0.412
# L6.ln_pvp_urea                        0.0213      0.094      0.227      0.821      -0.163       0.205
#   Det. terms outside the coint. relation & lagged endog. parameters for equation volatilidad_bdi_6m
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# exog1                                -0.1900      0.048     -3.972      0.000      -0.284      -0.096
# L1.ln_fob_urea_kg                     0.1944      0.060      3.215      0.001       0.076       0.313
# L1.ln_crude_oil_brent_usd_per_bbl    -0.0646      0.075     -0.864      0.387      -0.211       0.082
# L1.ln_ipc_diesel                     -0.4765      0.140     -3.401      0.001      -0.751      -0.202
# L1.volatilidad_bdi_6m                 0.1843      0.084      2.204      0.028       0.020       0.348
# L1.ln_inter_bdi_crude                -0.0548      0.036     -1.527      0.127      -0.125       0.016
# L1.coef_var_precip_12m                0.2793      0.289      0.967      0.334      -0.287       0.845
# L1.ln_pvp_urea                        0.2280      0.161      1.416      0.157      -0.088       0.544
# L2.ln_fob_urea_kg                     0.1181      0.059      1.992      0.046       0.002       0.234
# L2.ln_crude_oil_brent_usd_per_bbl     0.0261      0.075      0.349      0.727      -0.121       0.173
# L2.ln_ipc_diesel                     -0.5481      0.154     -3.564      0.000      -0.849      -0.247
# L2.volatilidad_bdi_6m                 0.0036      0.085      0.042      0.967      -0.163       0.170
# L2.ln_inter_bdi_crude                -0.0360      0.031     -1.150      0.250      -0.097       0.025
# L2.coef_var_precip_12m                0.5247      0.299      1.753      0.080      -0.062       1.111
# L2.ln_pvp_urea                       -0.0538      0.155     -0.348      0.728      -0.357       0.249
# L3.ln_fob_urea_kg                     0.0857      0.059      1.441      0.150      -0.031       0.202
# L3.ln_crude_oil_brent_usd_per_bbl    -0.0232      0.070     -0.330      0.741      -0.161       0.115
# L3.ln_ipc_diesel                     -0.7078      0.154     -4.592      0.000      -1.010      -0.406
# L3.volatilidad_bdi_6m                 0.0187      0.083      0.226      0.821      -0.144       0.181
# L3.ln_inter_bdi_crude                -0.0311      0.028     -1.100      0.271      -0.086       0.024
# L3.coef_var_precip_12m                0.4796      0.291      1.650      0.099      -0.090       1.049
# L3.ln_pvp_urea                        0.1229      0.152      0.808      0.419      -0.175       0.421
# L4.ln_fob_urea_kg                     0.0766      0.058      1.316      0.188      -0.038       0.191
# L4.ln_crude_oil_brent_usd_per_bbl     0.0107      0.070      0.154      0.877      -0.126       0.147
# L4.ln_ipc_diesel                     -0.4399      0.152     -2.885      0.004      -0.739      -0.141
# L4.volatilidad_bdi_6m                 0.0871      0.082      1.067      0.286      -0.073       0.247
# L4.ln_inter_bdi_crude                -0.0353      0.027     -1.287      0.198      -0.089       0.018
# L4.coef_var_precip_12m               -0.1575      0.280     -0.563      0.574      -0.706       0.391
# L4.ln_pvp_urea                        0.2613      0.143      1.822      0.068      -0.020       0.542
# L5.ln_fob_urea_kg                    -0.0087      0.054     -0.162      0.871      -0.114       0.096
# L5.ln_crude_oil_brent_usd_per_bbl    -0.0429      0.065     -0.659      0.510      -0.171       0.085
# L5.ln_ipc_diesel                     -0.4512      0.151     -2.996      0.003      -0.746      -0.156
# L5.volatilidad_bdi_6m                 0.0397      0.083      0.478      0.633      -0.123       0.202
# L5.ln_inter_bdi_crude                -0.0304      0.024     -1.292      0.196      -0.077       0.016
# L5.coef_var_precip_12m                0.2991      0.269      1.113      0.266      -0.228       0.826
# L5.ln_pvp_urea                        0.1729      0.127      1.358      0.175      -0.077       0.422
# L6.ln_fob_urea_kg                     0.0815      0.052      1.567      0.117      -0.020       0.183
# L6.ln_crude_oil_brent_usd_per_bbl    -0.0659      0.060     -1.097      0.273      -0.184       0.052
# L6.ln_ipc_diesel                     -0.7606      0.129     -5.876      0.000      -1.014      -0.507
# L6.volatilidad_bdi_6m                -0.4566      0.075     -6.081      0.000      -0.604      -0.309
# L6.ln_inter_bdi_crude                -0.0108      0.020     -0.531      0.595      -0.051       0.029
# L6.coef_var_precip_12m                0.3923      0.276      1.423      0.155      -0.148       0.933
# L6.ln_pvp_urea                       -0.2935      0.129     -2.277      0.023      -0.546      -0.041
#   Det. terms outside the coint. relation & lagged endog. parameters for equation ln_inter_bdi_crude
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# exog1                                 1.2386      0.244      5.071      0.000       0.760       1.717
# L1.ln_fob_urea_kg                    -1.0824      0.309     -3.507      0.000      -1.687      -0.478
# L1.ln_crude_oil_brent_usd_per_bbl    -0.2128      0.381     -0.558      0.577      -0.960       0.535
# L1.ln_ipc_diesel                      2.4992      0.715      3.495      0.000       1.097       3.901
# L1.volatilidad_bdi_6m                -1.8392      0.427     -4.309      0.000      -2.676      -1.003
# L1.ln_inter_bdi_crude                 0.4052      0.183      2.210      0.027       0.046       0.765
# L1.coef_var_precip_12m               -0.0954      1.475     -0.065      0.948      -2.986       2.795
# L1.ln_pvp_urea                       -0.3149      0.822     -0.383      0.702      -1.926       1.296
# L2.ln_fob_urea_kg                    -0.4777      0.303     -1.579      0.114      -1.071       0.115
# L2.ln_crude_oil_brent_usd_per_bbl    -0.7392      0.383     -1.932      0.053      -1.489       0.011
# L2.ln_ipc_diesel                      2.2572      0.785      2.875      0.004       0.718       3.796
# L2.volatilidad_bdi_6m                -1.4560      0.433     -3.361      0.001      -2.305      -0.607
# L2.ln_inter_bdi_crude                 0.5065      0.160      3.174      0.002       0.194       0.819
# L2.coef_var_precip_12m               -2.3854      1.528     -1.562      0.118      -5.379       0.609
# L2.ln_pvp_urea                        0.5552      0.790      0.703      0.482      -0.993       2.103
# L3.ln_fob_urea_kg                    -0.5853      0.303     -1.929      0.054      -1.180       0.009
# L3.ln_crude_oil_brent_usd_per_bbl    -0.1936      0.359     -0.540      0.589      -0.897       0.509
# L3.ln_ipc_diesel                      3.1285      0.787      3.976      0.000       1.586       4.671
# L3.volatilidad_bdi_6m                -1.4215      0.423     -3.360      0.001      -2.251      -0.592
# L3.ln_inter_bdi_crude                 0.3050      0.144      2.116      0.034       0.023       0.587
# L3.coef_var_precip_12m               -3.2172      1.484     -2.168      0.030      -6.125      -0.309
# L3.ln_pvp_urea                        1.4198      0.777      1.827      0.068      -0.103       2.943
# L4.ln_fob_urea_kg                    -0.7954      0.297     -2.677      0.007      -1.378      -0.213
# L4.ln_crude_oil_brent_usd_per_bbl     0.5425      0.355      1.528      0.126      -0.153       1.238
# L4.ln_ipc_diesel                      2.9227      0.778      3.755      0.000       1.397       4.448
# L4.volatilidad_bdi_6m                -1.9227      0.417     -4.611      0.000      -2.740      -1.105
# L4.ln_inter_bdi_crude                -0.0962      0.140     -0.687      0.492      -0.370       0.178
# L4.coef_var_precip_12m               -1.6601      1.429     -1.162      0.245      -4.460       1.140
# L4.ln_pvp_urea                       -0.4098      0.732     -0.560      0.576      -1.844       1.025
# L5.ln_fob_urea_kg                    -0.2967      0.273     -1.085      0.278      -0.832       0.239
# L5.ln_crude_oil_brent_usd_per_bbl    -0.0215      0.333     -0.065      0.949      -0.674       0.631
# L5.ln_ipc_diesel                      0.5367      0.769      0.698      0.485      -0.970       2.043
# L5.volatilidad_bdi_6m                -1.1955      0.423     -2.823      0.005      -2.025      -0.366
# L5.ln_inter_bdi_crude                 0.0052      0.120      0.043      0.966      -0.230       0.241
# L5.coef_var_precip_12m               -2.9360      1.372     -2.140      0.032      -5.625      -0.247
# L5.ln_pvp_urea                        1.4751      0.650      2.270      0.023       0.201       2.749
# L6.ln_fob_urea_kg                    -0.1470      0.266     -0.554      0.580      -0.668       0.373
# L6.ln_crude_oil_brent_usd_per_bbl     0.4149      0.306      1.354      0.176      -0.186       1.016
# L6.ln_ipc_diesel                     -2.1210      0.661     -3.210      0.001      -3.416      -0.826
# L6.volatilidad_bdi_6m                 0.4810      0.383      1.255      0.209      -0.270       1.232
# L6.ln_inter_bdi_crude                -0.0747      0.103     -0.722      0.470      -0.278       0.128
# L6.coef_var_precip_12m               -1.1691      1.407     -0.831      0.406      -3.928       1.590
# L6.ln_pvp_urea                       -0.3710      0.658     -0.564      0.573      -1.661       0.919
#   Det. terms outside the coint. relation & lagged endog. parameters for equation coef_var_precip_12m
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# exog1                                -0.0511      0.015     -3.347      0.001      -0.081      -0.021
# L1.ln_fob_urea_kg                     0.0114      0.019      0.593      0.553      -0.026       0.049
# L1.ln_crude_oil_brent_usd_per_bbl     0.0148      0.024      0.619      0.536      -0.032       0.061
# L1.ln_ipc_diesel                     -0.0314      0.045     -0.703      0.482      -0.119       0.056
# L1.volatilidad_bdi_6m                 0.0324      0.027      1.214      0.225      -0.020       0.085
# L1.ln_inter_bdi_crude                 0.0097      0.011      0.847      0.397      -0.013       0.032
# L1.coef_var_precip_12m                0.1952      0.092      2.118      0.034       0.015       0.376
# L1.ln_pvp_urea                        0.0287      0.051      0.559      0.576      -0.072       0.129
# L2.ln_fob_urea_kg                     0.0329      0.019      1.737      0.082      -0.004       0.070
# L2.ln_crude_oil_brent_usd_per_bbl    -0.0169      0.024     -0.706      0.480      -0.064       0.030
# L2.ln_ipc_diesel                     -0.0272      0.049     -0.555      0.579      -0.123       0.069
# L2.volatilidad_bdi_6m                 0.0019      0.027      0.069      0.945      -0.051       0.055
# L2.ln_inter_bdi_crude                 0.0101      0.010      1.011      0.312      -0.009       0.030
# L2.coef_var_precip_12m               -0.0176      0.095     -0.184      0.854      -0.205       0.170
# L2.ln_pvp_urea                       -0.0315      0.049     -0.638      0.523      -0.128       0.065
# L3.ln_fob_urea_kg                     0.0548      0.019      2.890      0.004       0.018       0.092
# L3.ln_crude_oil_brent_usd_per_bbl    -0.0221      0.022     -0.985      0.324      -0.066       0.022
# L3.ln_ipc_diesel                     -0.0439      0.049     -0.893      0.372      -0.140       0.052
# L3.volatilidad_bdi_6m                 0.0674      0.026      2.548      0.011       0.016       0.119
# L3.ln_inter_bdi_crude                 0.0168      0.009      1.863      0.062      -0.001       0.034
# L3.coef_var_precip_12m                0.1241      0.093      1.338      0.181      -0.058       0.306
# L3.ln_pvp_urea                        0.0155      0.049      0.320      0.749      -0.080       0.111
# L4.ln_fob_urea_kg                    -0.0093      0.019     -0.501      0.616      -0.046       0.027
# L4.ln_crude_oil_brent_usd_per_bbl    -0.0312      0.022     -1.409      0.159      -0.075       0.012
# L4.ln_ipc_diesel                      0.0212      0.049      0.435      0.664      -0.074       0.116
# L4.volatilidad_bdi_6m                 0.0051      0.026      0.195      0.846      -0.046       0.056
# L4.ln_inter_bdi_crude                 0.0069      0.009      0.784      0.433      -0.010       0.024
# L4.coef_var_precip_12m                0.1198      0.089      1.342      0.180      -0.055       0.295
# L4.ln_pvp_urea                        0.0399      0.046      0.872      0.383      -0.050       0.130
# L5.ln_fob_urea_kg                    -0.0254      0.017     -1.484      0.138      -0.059       0.008
# L5.ln_crude_oil_brent_usd_per_bbl    -0.0243      0.021     -1.168      0.243      -0.065       0.016
# L5.ln_ipc_diesel                     -0.0530      0.048     -1.103      0.270      -0.147       0.041
# L5.volatilidad_bdi_6m                 0.0770      0.026      2.908      0.004       0.025       0.129
# L5.ln_inter_bdi_crude                 0.0104      0.008      1.386      0.166      -0.004       0.025
# L5.coef_var_precip_12m                0.2068      0.086      2.412      0.016       0.039       0.375
# L5.ln_pvp_urea                        0.0872      0.041      2.147      0.032       0.008       0.167
# L6.ln_fob_urea_kg                    -0.0135      0.017     -0.816      0.414      -0.046       0.019
# L6.ln_crude_oil_brent_usd_per_bbl     0.0017      0.019      0.087      0.931      -0.036       0.039
# L6.ln_ipc_diesel                      0.0039      0.041      0.094      0.925      -0.077       0.085
# L6.volatilidad_bdi_6m                -0.0074      0.024     -0.310      0.757      -0.054       0.040
# L6.ln_inter_bdi_crude                 0.0044      0.006      0.677      0.498      -0.008       0.017
# L6.coef_var_precip_12m                0.0065      0.088      0.074      0.941      -0.166       0.179
# L6.ln_pvp_urea                       -0.0526      0.041     -1.279      0.201      -0.133       0.028
#       Det. terms outside the coint. relation & lagged endog. parameters for equation ln_pvp_urea
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# exog1                                 0.1031      0.032      3.265      0.001       0.041       0.165
# L1.ln_fob_urea_kg                     0.1242      0.040      3.113      0.002       0.046       0.202
# L1.ln_crude_oil_brent_usd_per_bbl     0.0838      0.049      1.699      0.089      -0.013       0.180
# L1.ln_ipc_diesel                      0.2505      0.092      2.709      0.007       0.069       0.432
# L1.volatilidad_bdi_6m                 0.0189      0.055      0.343      0.732      -0.089       0.127
# L1.ln_inter_bdi_crude                -0.0544      0.024     -2.296      0.022      -0.101      -0.008
# L1.coef_var_precip_12m               -0.1593      0.191     -0.836      0.403      -0.533       0.214
# L1.ln_pvp_urea                       -0.2169      0.106     -2.042      0.041      -0.425      -0.009
# L2.ln_fob_urea_kg                     0.0827      0.039      2.115      0.034       0.006       0.159
# L2.ln_crude_oil_brent_usd_per_bbl     0.1037      0.049      2.096      0.036       0.007       0.201
# L2.ln_ipc_diesel                      0.1273      0.101      1.255      0.210      -0.072       0.326
# L2.volatilidad_bdi_6m                 0.1305      0.056      2.330      0.020       0.021       0.240
# L2.ln_inter_bdi_crude                -0.0650      0.021     -3.150      0.002      -0.105      -0.025
# L2.coef_var_precip_12m               -0.2781      0.197     -1.408      0.159      -0.665       0.109
# L2.ln_pvp_urea                       -0.2362      0.102     -2.313      0.021      -0.436      -0.036
# L3.ln_fob_urea_kg                     0.1281      0.039      3.265      0.001       0.051       0.205
# L3.ln_crude_oil_brent_usd_per_bbl     0.0486      0.046      1.048      0.294      -0.042       0.140
# L3.ln_ipc_diesel                     -0.0064      0.102     -0.063      0.950      -0.206       0.193
# L3.volatilidad_bdi_6m                -0.0403      0.055     -0.737      0.461      -0.147       0.067
# L3.ln_inter_bdi_crude                -0.0359      0.019     -1.925      0.054      -0.072       0.001
# L3.coef_var_precip_12m                0.5713      0.192      2.979      0.003       0.195       0.947
# L3.ln_pvp_urea                       -0.2281      0.100     -2.270      0.023      -0.425      -0.031
# L4.ln_fob_urea_kg                     0.1310      0.038      3.409      0.001       0.056       0.206
# L4.ln_crude_oil_brent_usd_per_bbl    -0.0034      0.046     -0.074      0.941      -0.093       0.087
# L4.ln_ipc_diesel                     -0.0289      0.101     -0.287      0.774      -0.226       0.168
# L4.volatilidad_bdi_6m                -0.0047      0.054     -0.088      0.930      -0.110       0.101
# L4.ln_inter_bdi_crude                -0.0281      0.018     -1.556      0.120      -0.064       0.007
# L4.coef_var_precip_12m                0.1033      0.185      0.559      0.576      -0.259       0.465
# L4.ln_pvp_urea                       -0.0734      0.095     -0.776      0.438      -0.259       0.112
# L5.ln_fob_urea_kg                     0.0994      0.035      2.812      0.005       0.030       0.169
# L5.ln_crude_oil_brent_usd_per_bbl     0.0633      0.043      1.471      0.141      -0.021       0.148
# L5.ln_ipc_diesel                      0.1449      0.099      1.458      0.145      -0.050       0.340
# L5.volatilidad_bdi_6m                 0.0174      0.055      0.318      0.750      -0.090       0.125
# L5.ln_inter_bdi_crude                -0.0199      0.016     -1.279      0.201      -0.050       0.011
# L5.coef_var_precip_12m               -0.1027      0.177     -0.579      0.563      -0.450       0.245
# L5.ln_pvp_urea                        0.1211      0.084      1.441      0.150      -0.044       0.286
# L6.ln_fob_urea_kg                    -0.0021      0.034     -0.062      0.950      -0.069       0.065
# L6.ln_crude_oil_brent_usd_per_bbl    -0.0134      0.040     -0.338      0.735      -0.091       0.064
# L6.ln_ipc_diesel                      0.0530      0.085      0.621      0.535      -0.114       0.220
# L6.volatilidad_bdi_6m                -0.0353      0.050     -0.713      0.476      -0.132       0.062
# L6.ln_inter_bdi_crude                -0.0169      0.013     -1.260      0.208      -0.043       0.009
# L6.coef_var_precip_12m                0.0862      0.182      0.474      0.636      -0.270       0.443
# L6.ln_pvp_urea                        0.1570      0.085      1.846      0.065      -0.010       0.324
#            Loading coefficients (alpha) for equation ln_fob_urea_kg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.2139      0.092     -2.321      0.020      -0.395      -0.033
# ec2           -0.4198      0.113     -3.722      0.000      -0.641      -0.199
#    Loading coefficients (alpha) for equation ln_crude_oil_brent_usd_per_bbl
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0541      0.081     -0.667      0.505      -0.213       0.105
# ec2           -0.2243      0.099     -2.262      0.024      -0.419      -0.030
#            Loading coefficients (alpha) for equation ln_ipc_diesel
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0258      0.040     -0.643      0.520      -0.104       0.053
# ec2           -0.1020      0.049     -2.078      0.038      -0.198      -0.006
#          Loading coefficients (alpha) for equation volatilidad_bdi_6m
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.2179      0.055     -3.953      0.000      -0.326      -0.110
# ec2           -0.1344      0.067     -1.993      0.046      -0.267      -0.002
#          Loading coefficients (alpha) for equation ln_inter_bdi_crude
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            1.4449      0.281      5.136      0.000       0.894       1.996
# ec2            1.0286      0.344      2.988      0.003       0.354       1.703
#         Loading coefficients (alpha) for equation coef_var_precip_12m
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0076      0.018     -0.431      0.666      -0.042       0.027
# ec2            0.0277      0.022      1.287      0.198      -0.014       0.070
#             Loading coefficients (alpha) for equation ln_pvp_urea
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0316      0.036     -0.868      0.386      -0.103       0.040
# ec2           -0.1259      0.045     -2.828      0.005      -0.213      -0.039
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2       2.22e-16          0          0      0.000    2.22e-16    2.22e-16
# beta.3        -3.8264      0.404     -9.481      0.000      -4.617      -3.035
# beta.4         1.7461      0.357      4.897      0.000       1.047       2.445
# beta.5        -0.1119      0.274     -0.408      0.683      -0.649       0.426
# beta.6         2.5285      0.242     10.434      0.000       2.054       3.003
# beta.7        -1.0761      0.045    -24.127      0.000      -1.163      -0.989
# const         18.1627      0.039    460.942      0.000      18.086      18.240
#           Cointegration relations for loading-coefficients-column 2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1              0          0          0      0.000           0           0
# beta.2         1.0000          0          0      0.000       1.000       1.000
# beta.3         3.1555      0.620      5.090      0.000       1.940       4.371
# beta.4        -0.4728      0.548     -0.863      0.388      -1.546       0.601
# beta.5        -0.5296      0.130     -4.062      0.000      -0.785      -0.274
# beta.6        -1.3884      0.115    -12.052      0.000      -1.614      -1.163
# beta.7        -0.3538      1.935     -0.183      0.855      -4.146       3.438
# const        -12.4847      1.709     -7.304      0.000     -15.835      -9.134
# ==============================================================================

# %%
residuos_vecm = pd.DataFrame()

for var_name, resid in zip(df_endógenas_vecm.columns, modelo_vecm.resid.T):
    residuos_vecm["resid_" + var_name] = resid


residuos_vecm.index = pd.date_range(
    start=df_endógenas_vecm.index.min() + pd.DateOffset(months=maxlags_óptimo + 1),
    end=df_endógenas_vecm.index.max(),
    freq='ME'
    ) 


num_de_filas = ((residuos_vecm.shape[1] + 1) // 2)

residuos_vecm.plot(
    subplots=True,
    layout=(num_de_filas, 2), # filas, columnas
    figsize=(15, 2 * num_de_filas),
    sharex=False
    )
plt.suptitle("Gráfico de estacionareidad de los residuos")
plt.tight_layout()
plt.show()

# %% [markdown]
# En un modelo VECM, la estacionariedad de los residuos es esencial para garantizar que las relaciones entre las variables estén correctamente especificadas y que el modelo no omita dinámicas importantes. Si los residuos no son estacionarios, esto podría indicar la presencia de patrones no capturados, como tendencias o ciclos, lo que comprometería la validez de las inferencias realizadas. Además, la estacionariedad previene problemas como las relaciones espurias, asegurando que las estimaciones reflejen vínculos económicos reales y no coincidencias estadísticas.
#
# La evaluación conjunta de estacionariedad mediante las pruebas **Augmented Dickey-Fuller** (ADF) y **Kwiatkowski-Phillips-Schmidt-Shin** (KPSS) permite obtener una perspectiva más completa sobre la naturaleza de las series temporales. Estas pruebas abordan la estacionariedad desde enfoques opuestos: ADF detecta la presencia de raíces unitarias (es decir, no estacionariedad) asumiendo como hipótesis nula que la serie no es estacionaria, mientras que KPSS evalúa si existe tendencia o estructura no estacionaria, partiendo de la hipótesis nula de que la serie es estacionaria.
#
# La combinación de ambos resultados facilita una evaluación robusta de la estacionareidad de los residuos. Una serie se considera estacionaria si ADF rechaza su hipótesis nula (p-valor bajo) y KPSS no la rechaza (p-valor alto). Por el contrario, se considera no estacionaria si ADF no rechaza su hipótesis nula (p-valor alto) o KPSS sí la rechaza (p-valor bajo). Este enfoque evita depender únicamente de un test, aumentando la precisión y confiabilidad del análisis.

# %%
# Evaluar estacionareidad de residuos del modelo VECM utilizando ADF y KPSS:
evaluar_estacionareidad_residuos_vecm = evaluar_estacionareidad(residuos_vecm)

evaluar_estacionareidad_residuos_vecm
# Out:
#                                variable  valor_p_adfuller  valor_p_kpss  \
# 0                  resid_ln_fob_urea_kg      3.195720e-20           0.1
# 1  resid_ln_crude_oil_brent_usd_per_bbl      1.955350e-19           0.1
# 2                   resid_ln_ipc_diesel      3.333666e-21           0.1
# 3              resid_volatilidad_bdi_6m      1.397614e-13           0.1
# 4              resid_ln_inter_bdi_crude      1.412331e-18           0.1
# 5             resid_coef_var_precip_12m      1.430745e-20           0.1
# 6                     resid_ln_pvp_urea      4.302294e-22           0.1
#
#    adfuller_rechazar_H0  kpss_rechazar_H0 estado_estacionario
# 0                  True             False        Estacionario
# 1                  True             False        Estacionario
# 2                  True             False        Estacionario
# 3                  True             False        Estacionario
# 4                  True             False        Estacionario
# 5                  True             False        Estacionario
# 6                  True             False        Estacionario

# %% [markdown]
# La **prueba de Ljung-Box** evalúa si los residuos de un modelo de series temporales son independientes, es decir, si no presentan autocorrelación. La independencia de los residuos garantiza que el modelo haya capturado adecuadamente las dinámicas de las variables y no existan patrones no modelados.
#
# La hipótesis nula de la prueba plantea que no hay autocorrelación en los residuos, mientras que la hipótesis alternativa sugiere lo contrario. Un p-valor alto indica que los residuos son independientes, mientras que un p-valor bajo señala la presencia de autocorrelación y la posible necesidad de ajustar el modelo.
#
# En modelos como el VECM, la prueba de Ljung-Box es clave para confirmar que las relaciones temporales han sido correctamente especificadas y que las inferencias basadas en el modelo son confiables.

# %%
import pandas as pd
from statsmodels.stats.diagnostic import acorr_ljungbox

# Crear una lista para almacenar los resultados
resultados_ljung_box = []

# Iterar sobre cada columna (variable) del DataFrame de residuos
for column in residuos_vecm.columns:
    # Ejecutar la prueba de Ljung-Box
    ljung_box = acorr_ljungbox(residuos_vecm[column], lags=10, return_df=True)  # lags = número de retardos
    
    # Extraer los resultados finales (último lag)
    lb_stat = ljung_box['lb_stat'].iloc[-1]
    lb_pvalue = ljung_box['lb_pvalue'].iloc[-1]
    
    # Veredicto: Si p-valor > 0.05, no hay autocorrelación (residuos son aleatorios)
    veredicto = "Sin autocorrelación" if lb_pvalue > 0.05 else "Autocorrelación presente"
    
    # Agregar los resultados a la lista
    resultados_ljung_box.append({
        "variable": column,
        "lb_stat": lb_stat,
        "lb_pvalue": lb_pvalue,
        "veredicto": veredicto
    })

# Convertir los resultados en un DataFrame
df_ljung_box = pd.DataFrame(resultados_ljung_box)

# Mostrar el DataFrame
df_ljung_box
# Out:
#                                variable   lb_stat  lb_pvalue  \
# 0                  resid_ln_fob_urea_kg  9.007263   0.531414
# 1  resid_ln_crude_oil_brent_usd_per_bbl  1.506599   0.998915
# 2                   resid_ln_ipc_diesel  7.513494   0.676240
# 3              resid_volatilidad_bdi_6m  7.839975   0.644465
# 4              resid_ln_inter_bdi_crude  4.519830   0.920866
# 5             resid_coef_var_precip_12m  7.999911   0.628846
# 6                     resid_ln_pvp_urea  5.190220   0.878114
#
#              veredicto
# 0  Sin autocorrelación
# 1  Sin autocorrelación
# 2  Sin autocorrelación
# 3  Sin autocorrelación
# 4  Sin autocorrelación
# 5  Sin autocorrelación
# 6  Sin autocorrelación

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
import math

def plot_acf_subplots(data, lags=20, figsize=(12, 8)):
    """
    Grafica las funciones de autocorrelación (ACF) de varias variables como subplots en dos columnas.
    
    Parámetros:
        data (pd.DataFrame): DataFrame que contiene las series temporales a analizar.
        lags (int): Número de rezagos para calcular la ACF.
        figsize (tuple): Tamaño total de la figura.
        
    Retorna:
        None: Muestra los gráficos en subplots.
    """
    # Número total de variables
    num_vars = data.shape[1]
    
    # Calcular el número de filas para organizar los subplots en dos columnas
    num_rows = math.ceil(num_vars / 2)
    
    # Crear la figura y los subplots
    fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=figsize)
    fig.tight_layout(pad=4.0)  # Espaciado entre gráficos
    
    # Aplanar los ejes si hay más de una fila para un manejo uniforme
    axes = axes.flatten()

    # Graficar la ACF de cada variable en su subplot
    for i, column in enumerate(data.columns):
        plot_acf(data[column].dropna(), ax=axes[i], lags=lags, title=f"ACF de {column}")
        axes[i].title.set_size(10)
    
    # Ocultar subplots vacíos si hay un número impar de variables
    for j in range(len(data.columns), len(axes)):
        fig.delaxes(axes[j])

    # Mostrar la figura
    plt.suptitle("Gráfica de función de autocorrelación de las variables")
    plt.tight_layout()
    plt.show()

# %%
plot_acf_subplots(residuos_vecm, lags=20)

# %% [markdown]
# #### Homocedasticidad de residuos

# %%
for col in residuos_vecm.columns:

    # Calcular estadísticos de heterocedasticidad:
    lm_stat, p_value = check_homoscedasticity(residuos_vecm[col])
    
    # Imprimir estadísticos:
    print(f"{col} ->  p-value: {p_value}")
    
    # Filtrar variables con evidencia de heterocedasticidad:
# Out:
# resid_ln_fob_urea_kg ->  p-value: 0.875
# resid_ln_crude_oil_brent_usd_per_bbl ->  p-value: 0.187
# resid_ln_ipc_diesel ->  p-value: 0.485
# resid_volatilidad_bdi_6m ->  p-value: 0.13
# resid_ln_inter_bdi_crude ->  p-value: 0.774
# resid_coef_var_precip_12m ->  p-value: 0.236
# resid_ln_pvp_urea ->  p-value: 0.506

# %%
plot_homoscedasticity(residuos_vecm)

# plot_ccf_subplots(df_estacionarios, X.columns.tolist(), variable_objetivo, max_lag=30, palette_name="tab20")
# ola k ase
